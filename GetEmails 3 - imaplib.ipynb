# %%
import json
import os

import email
import imaplib

# %%
import json
path_creds = "F:/Data/DataBases/creds.json"

with open(path_creds, encoding="utf-8-sig") as f:
    info = json.load(f)

ID = info["ID"]
host = info["host"]
user = info["users"]
pw = info["pw"]

# print("Host: {}, User: {}, PW: {}".format(host, user, pw))

# %% [markdown]
# # Sending and receiving emails with Python
# Published on August 10, 2018 - [Humberto Rocha](https://humberto.io/blog/sending-and-receiving-emails-with-python/)
#
# Email systems are robust because they rely upon well-established protocols used by all email platforms across the internet. These protocols are defined and published by documents called RFC that stands for Request for Comments and resemble the PEPs from Python, but for protocols and patterns that define the operation of communication systems through the internet.
#
# To send emails, we use the SMTP protocol (RFCs 821 e 5321), and to receive them, we use IMAP (RFC 3501) or POP (RFCs 918 e 1081) protocols.

# %% [markdown]
# ## 2. Receiving emails
# The IMAP Internet Message Access Protocol is used to receive emails, and as on SMTP it operates at the application layer over TCP/IP. The port used for its connections is 143 for unencrypted and 993 for encrypted.
#
# Another protocol that works for this task is POP Post Office Protocol, but IMAP is better due to its synchronization between the client and the server and also the ability to access more than the email inbox.
#
# The process of receiving emails is more complicated than sending because you also have to search for the message and decode it:

# %%
EMAIL = user           # 'mymail@mail.com'
PASSWORD = pw        # 'password'
SERVER = host        # 'imap.gmail.com'

# connect to the server and go to its inbox
mail = imaplib.IMAP4_SSL(SERVER)
mail.login(EMAIL, PASSWORD)
# we choose the inbox but you can select others

folder = '"2 Check"' # 'INBOX'  ACHTUNG Umlaufende Quotation Marks setzen !
# folder = 'BK' # 'INBOX'  ACHTUNG Umlaufende Quotation Marks setzen !

mail.select(folder)
# mail.list()
# Out:
# ('OK', [b'64'])

# %%
# we'll search using the ALL criteria to retrieve
# every message inside the inbox
# it will return with its status and a list of ids
status, data = mail.search(None, 'ALL')
# the list returned is a list of bytes separated
# by white spaces on this format: [b'1 2 3', b'4 5 6']
# so, to separate it first we create an empty list
mail_ids = []
# then we go through the list splitting its blocks
# of bytes and appending to the mail_ids list
for block in data:
    # the split function called without parameter
    # transforms the text or bytes into a list using
    # as separator the white spaces:
    # b'1 2 3'.split() => [b'1', b'2', b'3']
    mail_ids += block.split()

# now for every id we'll fetch the email
# to extract its content
for i in mail_ids:
    # the fetch function fetch the email given its id
    # and format that you want the message to be
    status, data = mail.fetch(i, '(RFC822)')

    # the content data at the '(RFC822)' format comes on
    # a list with a tuple with header, content, and the closing
    # byte b')'
    for response_part in data:
        # so if its a tuple...
        if isinstance(response_part, tuple):
            # we go for the content at its second element
            # skipping the header at the first and the closing
            # at the third
            message = email.message_from_bytes(response_part[1])

            # with the content we can extract the info about
            # who sent the message and its subject
            mail_from = message['from']
            mail_subject = message['subject']

            # then for the text we have a little more work to do
            # because it can be in plain text or multipart
            # if its not plain text we need to separate the message
            # from its annexes to get the text
            if message.is_multipart():
                mail_content = ''

                # on multipart we have the text message and
                # another things like annex, and html version
                # of the message, in that case we loop through
                # the email payload
                for part in message.get_payload():
                    # if the content type is text/plain
                    # we extract it
                    if part.get_content_type() == 'text/plain':
                        mail_content += part.get_payload()
            else:
                # if the message isn't multipart, just extract it
                mail_content = message.get_payload()

            # and then let's show its result
            print("#"*40+" NEXT EMAIL "+"#"*40)
            print(f'From: {mail_from}')
            print(f'Subject: {mail_subject}')
            print(f'Content: {mail_content}')
# Out:
# ######################################## NEXT EMAIL ########################################
# From: "Aboalarm GmbH" <receipts+k6Blo61skcL6x0thb2Cy@stripe.com>
# Subject: Your Aboalarm GmbH receipt [#1912-5086]
# Content:
#
#
# Thanks for your €1.49 payment to Aboalarm GmbH.
#
#
#
#
#
#
# €1.49 at  <http://www.aboalarm.de> Aboalarm GmbH
#
#
#
#
#
#
#
#
#   <https://stripe-images.s3.amazonaws.com/emails/receipt_assets/card/mastercard-light.png>
#
# 8269
#
#
#
#
#
#
# August 25, 2015 	#1912-5086
#
#
#
#
#
#
# Description 	Price
#
#
#
#
# Fax-Versand ID: WCW6UR 	€1.49
#
#
#
#
#
# Total 	€1.49
#
#
#
#
#
# You can contact us with any questions by emailing  <mailto:info@aboalarm.de>
# info@aboalarm.de
#
#
#
#
#
#
#
#
# Something wrong with the email?
# <https://dashboard.stripe.com/emails/receipts/pmtrc_16djfsI0tTguhMStj8yj7DcK>
# View it in your browser.
#
#
# You are receiving this email because you made a purchase at
# <http://www.aboalarm.de> Aboalarm GmbH.
#
#   <https://m2g7tpny.emltrk.com/m2g7tpny?d=none>
#
# ######################################## NEXT EMAIL ########################################
# From: "Central Krankenversicherung" <info@central.de>
# Subject: Ihr Dialog mit der Central
# Content: Sehr geehrte Damen und Herren,
#
# Ihr am 16.10.2015 um 16:39:55h unter Angabe der E-Mail Adresse
# „barth.andreas@web.de“ abgeschicktes Formular "Aktualisierung meiner Daten"
# ist bei uns eingetroffen – vielen Dank dafür!
#
# Im abgeschickten Formular haben Sie folgender Einwilligungserklärung
# zugestimmt:
# "Ich bin damit einverstanden, dass die Central Krankenversicherung meine
# E-Mail Adresse und Telefonnummer sowie Informationen zu meinem Vertrag mit
# Ausnahme von Gesundheitsdaten nutzt, um mich über neue Produkte und
# Serviceangebote der Central zu informieren. Dies gilt auch für die
# Durchführung von Kundenzufriedenheitsbefragungen durch
# Marktforschungsunternehmen. Diese Erklärung kann ich jederzeit ohne Angabe
# von Gründen widerrufen."
#
# Hier für Sie alle wichtigen Central-Kontakte auf einen Blick:
#
# (KundenService) für Ihre allgemeinen Fragen: 0221 1636-0
# (KundenService) für Ihre Leistungsfragen: 0221 1636-2960
# (KundenService) für Ihre Vertragsfragen: 0221 1636-2980
# Faxnummer für alle Fälle: 0221 1636-200
# E-Mail-Adresse für Ihre Anliegen: kundenservice@central.de
# Ihr KundenService ist Montag bis Freitag von 8 - 19 Uhr für Sie da.
#
# Ihre Central Krankenversicherung.
#
#
# Bitte beachten Sie, dass die Central Krankenversicherung AG aus Sicherheits-
# und aus Datenschutzgründen im E-Mail Verkehr keine personenbezogenen Daten
# übermittelt. Dazu gehören z.B. Adressen, Geburtsdaten, Bankverbindungen,
# Versicherungsscheinnummern und Diagnosen.
# __________________________________________________________________________
#
# Central Krankenversicherung AG
# Hansaring 40-50
# 50670 Köln
#
# Vorsitzender des Aufsichtsrates: Prof. h.c. (RUS) Dr. Wolfgang Kaske
# Vorstand: Dr. Jochen Petin (Vors.), Hans-Herbert Rospleszcz
# Sitz Köln · Amtsgericht Köln HR B 93
#
#
# ######################################## NEXT EMAIL ########################################
# From: "www.peterkleine.com" <mail@peterkleine.com>
# Subject: Mail vom 13.12.2015
# Content:
# Moin Andreas!
# Ich hoffe, es geht Dir gut und die OP ist gut verlaufen?
# Wie versprochen sende ich Dir mal ein paar Infos über unser kleines
# Start-up!
#
# Wäre gut, wenn das nicht jeder lesen würde, okay?
#
# Wir schnacken!
#
# LG,
# P.
#
#
# Keyfacts:
# pellybay gmbh
# An der Alster 18
# 20099 Hamburg
# Gründung 8.1.2013 aus der GmbH "Boutique de Films"
# Neueröffnung am 15.5.2013
# Angestellte:
# Philip, Head of Production
# Marie, PA
# Lars, PA
# Gesellschafter: Seydlitz und Kleine zu je 50%.
# GF: Seydlitz (nicht aktiv), Bothe (nicht aktiv), Kleine (richtig aktiv)
#
#
# Warum gibt es pellybay?
# 1. Bewegtbild für Unternehmen wird es immer geben
# 2. Unternehmen benötigen in immer kürzeren Abständen gutes Bewegtbild
# 3. Bewegtbild, Umsetzung und Endfertigung liegen immer mehr in einer Hand,
# da Technik und Software günstig sind.
# Jeder kann technisch zwar alles machen aber das Beste unterscheidet sich vom
# Guten immer noch an der Idee und seiner Umsetzung!
# 4. Unternehmen geben aber immer weniger Geld für Ideen zu Bewegtbild aus
# 5. diejenigen, die die Ideen zu Bewegtbild produzieren (Agenturen) schöpfen
# sehr viel Geld im Prozess ab, sodass für die Produktion wenig bleibt, um
# qualitativ Hochwertiges zu liefern oder Regisseure einzukaufen, die die
# Ideen auf eben das Niveau bringen.
# 6. pellybay kann durch seine Expertise und Erfahrung zum einen sehr gute
# Ideen für Bewegtbild liefern und diese umsetzen.
#
#
# Das Geschäftsmodell und der Ablauf:
# 1. Ein Unternehmen benötigt eine Idee für ein Bewegtbild.
# 2. Das Unternehmen gibt pellybay ein Briefing.
# 3. pellybay liefert Ideen -gegen Geld.
# 4. pellybay setzt die Idee um -gegen Geld.
#
# Vorteile für das Unternehmen/den Kunden:
# - extrem hohe Kostenersparniss, da sich Unternehmen die Schnittstelle
# Agentur spart
# - extrem hohe Zeitersparniss, Stichwort: kurze Wege
#
# unsre Zielgruppe:
# - Marketingentscheider in Unternehmen
# - Inhaber von Unternehmen
# - Gründer von Unternehmen (Start-ups)
# - Investoren
#
# Probleme:
# - Kunden denken, dass wir kein "Marketing" im klassischen Sinn können
# würden.
# - das Marketing für pellybay wurde aufgrund des einigermaßen guten Starts
# versäumt
# - die Vertriebsstruktur muss weiter aufgebaut werden
#
# Philosophie:
# wir wollen unsere Kunden besser machen! Das geht nur, wenn wir besser sind.
#
# Wettbewerber:
# Keine.
# In D, A,CH bieten viele Filmproduktionen sogenannte "Directors Rooms" an.
# Diese werden aber nicht
# angenommen, da alle75 im Markt tätigen Filmproduktionen zu 94% Jobs von
# Agenturen bekommen.
# Würden diese jetzt beginnen direkt mit dem Kunden zu arbeiten, würde ihnen
# sofort eine Hauptumsatzquelle
# wegbrechen.
#
# Ziel 2016:
# - Ausbau des Kreativdepartments
# - Ausbau des übergeordneten kaufmännisches Bereiches
# - Umsetzung des Marketing-, und Vertriebplans
# - deutlichere Wahrnehmung von pellybay als Marke hinsichtlich einer
# hochkreativen Bewegtbildfirma
#
#
# --
# ﻿PETER KLEINE www.peterkleine.com <http://www.peterkleine.com>
#
# ######################################## NEXT EMAIL ########################################
# From: "Andreas Barth" <barth.andreas@web.de>
# Subject: Change of Adress - Primary 538070
# Content:

# %%
import win32com.client

# %%
my_outlook = win32com.client.Dispatch("Outlook.Application").GetNamespace("MAPI")

folder = outlook.GetDefaultFolder(6) #index 
for item in folder.Items:
   print(item.body)
